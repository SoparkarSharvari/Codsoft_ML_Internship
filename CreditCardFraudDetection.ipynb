# %% [markdown]
# ### CREDIT CARD FRAUD DETECTION
#
# ##### Build a model to detect fraudulent credit card transactions. Use a dataset containing information about credit card transactions, and experiment with algorithms like Logistic Regression, Decision Trees, or Random Forests to classify transactions as fraudulent or legitimate.

# %% [markdown]
# #### In this project, we are examining the Credit Card Transactions Fraud Detection Dataset which contains both a training dataset and a training dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as mtick
import plotly.express as px

# %%
df=pd.read_csv('/Users/sharvarisoparkar/Downloads/credit card dataset/fraudtrain.csv')

# %%
df.isna().sum()
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %%
data=df.drop('Unnamed: 0',axis='columns')

# %%
data.drop_duplicates(inplace=True)
data
# Out:
#        trans_date_trans_time            cc_num  \
# 0        2020-06-21 12:14:25  2291163933867244
# 1        2020-06-21 12:14:33  3573030041201292
# 2        2020-06-21 12:14:53  3598215285024754
# 3        2020-06-21 12:15:15  3591919803438423
# 4        2020-06-21 12:15:17  3526826139003047
# ...                      ...               ...
# 555714   2020-12-31 23:59:07    30560609640617
# 555715   2020-12-31 23:59:09  3556613125071656
# 555716   2020-12-31 23:59:15  6011724471098086
# 555717   2020-12-31 23:59:24     4079773899158
# 555718   2020-12-31 23:59:34  4170689372027579
#
#                                     merchant        category     amt    first  \
# 0                      fraud_Kirlin and Sons   personal_care    2.86     Jeff
# 1                       fraud_Sporer-Keebler   personal_care   29.84   Joanne
# 2       fraud_Swaniawski, Nitzsche and Welch  health_fitness   41.28   Ashley
# 3                          fraud_Haley Group        misc_pos   60.05    Brian
# ...

# %%
import datetime as dt

train=pd.read_csv('/Users/sharvarisoparkar/Downloads/credit card dataset/fraudtrain.csv')
train['age']=dt.date.today().year-pd.to_datetime(train['dob']).dt.year
train['hour']=pd.to_datetime(train['trans_date_trans_time']).dt.hour
train['day']=pd.to_datetime(train['trans_date_trans_time']).dt.dayofweek
train['month']=pd.to_datetime(train['trans_date_trans_time']).dt.month
train=train[['category','amt','zip','lat','long','city_pop','merch_lat','merch_long','age','hour','day','month','is_fraud']]
#convert category to dummy variables
from sklearn.preprocessing import LabelEncoder

# Assuming you have a DataFrame 'new_df' and you want to label encode the 'category' column
label_encoder = LabelEncoder()
train['category_encoded'] = label_encoder.fit_transform(train['category'])
train_data =train.drop('category',axis='columns')

# %%
y_train=train_data['is_fraud'].values
X_train=train_data.drop("is_fraud", axis='columns').values

# %%
test=pd.read_csv('/Users/sharvarisoparkar/Downloads/credit card dataset/fraudTest.csv')
test['age']=dt.date.today().year-pd.to_datetime(test['dob']).dt.year
test['hour']=pd.to_datetime(test['trans_date_trans_time']).dt.hour
test['day']=pd.to_datetime(test['trans_date_trans_time']).dt.dayofweek
test['month']=pd.to_datetime(test['trans_date_trans_time']).dt.month
test=test[['category','amt','zip','lat','long','city_pop','merch_lat','merch_long','age','hour','day','month','is_fraud']]
#convert category to dummy variables
#test=pd.get_dummies(test, drop_first=True)
from sklearn.preprocessing import LabelEncoder

# Assuming you have a DataFrame 'new_df' and you want to label encode the 'category' column
label_encoder = LabelEncoder()
test['category_encoded'] = label_encoder.fit_transform(test['category'])
test_data=test.drop('category',axis='columns')

# %%
y_test=test_data['is_fraud'].values
X_test=test_data.drop("is_fraud", axis='columns').values

# %%
test_data=test.drop('category',axis='columns')
train_data =train.drop('category',axis='columns')

# %%
#random forest 
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier

method= SMOTE()
X_resampled, y_resampled = method.fit_resample(X_train, y_train)

# %%
model2 = RandomForestClassifier(random_state=5)
model2.fit(X_resampled,y_resampled)
# Out:
# RandomForestClassifier(random_state=5)

# %%
predict_data=[['personal_care',2.86,29209,33.9659,-80.9355,333497,33.986391,-81.200714,34,20,1,1]]
new_df=pd.DataFrame(predict_data,columns=['category','amt','zip','lat','long','city_pop','merch_lat','merch_long','age','hour','day','month'])

# Convert categorical variables to dummy variables for 'category'
# Convert the 'category' column into dummy variables
category_dummies = pd.get_dummies(new_df['category'], prefix='category')

# Drop the original 'category' column from 'new_df'
new_df = new_df.drop('category', axis=1)

# Concatenate the dummy variables with 'new_df'
new_df = pd.concat([new_df, category_dummies], axis=1)


new_df

# predictions = model2.predict(new_df)
# Out:
#     amt    zip      lat     long  city_pop  merch_lat  merch_long  age  hour  \
# 0  2.86  29209  33.9659 -80.9355    333497  33.986391  -81.200714   34    20
#
#    day  month  category_personal_care
# 0    1      1                       1

# %%
predictions = model2.predict(new_df)
predictions
# Out:
# /Users/sharvarisoparkar/anaconda3/lib/python3.10/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
import pickle
filename='model.sav'
pickle.dump(model2,open(filename,'wb'))
local_model=pickle.load(open(filename,'rb'))

# %%
r=local_model.score(X_test,y_test)
r
# Out:
# 0.9983552838754838
